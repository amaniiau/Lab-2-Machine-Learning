# %%
import pandas as pd
from IPython.display import display

df = pd.read_csv("Heart_Disease_Prediction.csv")
shape_df = pd.DataFrame({"Rows":[df.shape[0]], "Columns":[df.shape[1]]})
display(shape_df)

first_five_df = df.head(5)
display(first_five_df)

first_five_df.to_excel("first_5_records.xlsx", index=False)

columns_df = pd.DataFrame({"Column Name": df.columns})
display(columns_df)

dtypes_df = pd.DataFrame({"Column Name": df.columns, "Data Type": df.dtypes.values})
display(dtypes_df)
# Out:
#    Rows  Columns
# 0   270       14
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...
